# %% [markdown]
# <a href="https://colab.research.google.com/github/cheesss/anci_test/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
# !pip install ccxt

# %%
# !pip install finance-dataReader

# %%
import ccxt
import time
import numpy as np
import pandas as pd
import FinanceDataReader as fdr
import matplotlib.pyplot as plt

# %%
df = fdr.DataReader('BTC/USD', '2016')
df['Close'].plot()

# %%
import socket
 
print("Host Name ",socket.gethostname())
 
print("IP Address(Internal) : ",socket.gethostbyname(socket.gethostname()))
# Out:
# Host Name  806a381a4f10
# IP Address(Internal) :  172.28.0.2

# %%
binance = ccxt.binance({
'apiKey' : 'HIrj8C1XNJ8Kwixy2r9gI88qctSaNTmOlN21X9lqaBecfrvY2OYcDxY8KYVKuMmI',
'secret': 'ablrvg1GXmaXrtgEB6DzEidHiXPaVWvqbdWAlrkCQMZXpZP4vWXTLmgzT1ciuPVv',
'options': {
'defaultType': 'spot',
'adjustForTimeDifference': True
},
'enableRateLimit': True
})
 
binance_f = ccxt.binance({
'apiKey' : 'HIrj8C1XNJ8Kwixy2r9gI88qctSaNTmOlN21X9lqaBecfrvY2OYcDxY8KYVKuMmI',
'secret': 'ablrvg1GXmaXrtgEB6DzEidHiXPaVWvqbdWAlrkCQMZXpZP4vWXTLmgzT1ciuPVv',
'options': {
'defaultType': 'future',
'adjustForTimeDifference': True
},
'enableRateLimit': True
})

binance_d = ccxt.binance({
'apiKey' : 'HIrj8C1XNJ8Kwixy2r9gI88qctSaNTmOlN21X9lqaBecfrvY2OYcDxY8KYVKuMmI',
'secret': 'ablrvg1GXmaXrtgEB6DzEidHiXPaVWvqbdWAlrkCQMZXpZP4vWXTLmgzT1ciuPVv',
'options': {
'defaultType': 'delivery',
'adjustForTimeDifference': True
},
'enableRateLimit': True
})

# %%
time = '1d'
df = binance.fetch_ohlcv(symbol = 'BTC/USDT', timeframe = time, limit = 500)
df = pd.DataFrame(df, columns=['datetime', 'open', 'high', 'low', 'close', 'volume'])
df['datetime'] = pd.to_datetime(df['datetime'], unit='ms')
# df.set_index('datetime', inplace=True)
df_f = binance_f.fetch_ohlcv(symbol = 'BTC/USDT', timeframe = time, limit = 500)
df_f = pd.DataFrame(df_f, columns=['datetime', 'open', 'high', 'low', 'close', 'volume'])
df_f['datetime'] = pd.to_datetime(df_f['datetime'], unit='ms')
df_f['diff'] = (1-(df["close"]/df_f['close']))*100
df_f['diff_change'] = (df_f['diff'] - df_f['diff'].shift(1)) / df_f['diff']
df_f['change'] = (df_f['close'] - df_f['close'].shift(1)) / df_f['close'] * 100

plt.plot(df["datetime"],df['close'],'r', df['datetime'], df_f['close'],'b')
plt.title('spot-future')

plt.figure()
plt.plot(df['datetime'], df_f['diff'],'g')

plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
a = 0
b = a
buy_time = []
buy_price = []
df_co = pd.DataFrame({'a':df_f['diff'],'b':df_f['change']})
df_co = df_co.fillna(method='bfill')
for A, B, C in zip(df_f['close'],df['close'],df['datetime']):
    if A>=B:
        a += 1
        buy_time.append(C)
        buy_price.append(A)
    else:
        b += 1
    
buy = np.column_stack((buy_time, buy_price))
buy = pd.DataFrame(buy, columns=['datetime','close'])
print(buy)
print(a,b)

train_s = np.array(df_co['a'])
train_m = np.array(df_co['b'])

train_input, test_input, train_target,test_target = train_test_split(
    train_s, train_m, random_state=500
)

train_input = train_input.reshape(-1,1)
test_input = test_input.reshape(-1,1)
lr = LinearRegression()
lr.fit(train_input, train_target)
# Out:
#                datetime    close
# 0   2023-01-16 16:18:00  21023.0
# 1   2023-01-16 16:19:00  21026.8
# 2   2023-01-16 16:20:00  21030.4
# 3   2023-01-16 16:21:00  21031.8
# 4   2023-01-16 16:22:00  21034.9
# ..                  ...      ...
# 908 2023-01-17 08:19:00  21171.2
# 909 2023-01-17 08:20:00  21183.1
# 910 2023-01-17 08:22:00  21182.4
# 911 2023-01-17 08:25:00  21180.7
# 912 2023-01-17 08:33:00  21177.8
#
# [913 rows x 2 columns]
# 913 87
# LinearRegression()

# %%
print(lr.score(train_input, train_target))
print(lr.score(test_input, test_target))
# Out:
# 0.049907207327390735
# -0.035174172489313094

# %%
df2 = fdr.DataReader('FRED:FEDFUNDS', data_source='fred')
print(df2.tail(1))
df2.plot()
# Out:
#             FEDFUNDS
# DATE
# 2022-12-01       4.1

# %%
df1 = binance.fetch_ohlcv(symbol = 'BTC/USDT', timeframe = time, limit = 100)
df1 = pd.DataFrame(df1, columns=['datetime', 'open', 'high', 'low', 'close', 'volume'])
df1['datetime'] = pd.to_datetime(df1['datetime'], unit='ms')
df_d = binance.fetch_ohlcv(symbol = 'BTC/USDT', timeframe = time, limit = 100)
df_d = pd.DataFrame(df_d, columns=['datetime', 'open', 'high', 'low', 'close', 'volume'])
df_d['datetime'] = pd.to_datetime(df_d['datetime'], unit='ms')


plt.plot(df1["datetime"],df1['close']-df_d['close'])

# %%
bybit = ccxt.binance({
'options': {
'defaultType': 'spot',
'adjustForTimeDifference': True
},
'enableRateLimit': True
})

bybit.fetch_tickers()
# Out:
# {'ETH/BTC': {'symbol': 'ETH/BTC',
#   'timestamp': 1674109714305,
#   'datetime': '2023-01-19T06:28:34.305Z',
#   'high': 0.074555,
#   'low': 0.073023,
#   'bid': 0.073385,
#   'bidVolume': 17.0257,
#   'ask': 0.073386,
#   'askVolume': 23.8475,
#   'vwap': 0.07390685,
#   'open': 0.074482,
#   'close': 0.073385,
#   'last': 0.073385,
#   'previousClose': 0.074482,
#   'change': -0.001097,
#   'percentage': -1.473,
#   'average': 0.0739335,
#   'baseVolume': 67544.7432,
#   'quoteVolume': 4992.01943775,
#   'info': {'symbol': 'ETHBTC',
#    'priceChange': '-0.00109700',
#    'priceChangePercent': '-1.473',
#    'weightedAvgPrice': '0.07390685',
#    'prevClosePrice': '0.07448200',
#    'lastPrice': '0.07338500',
#    'lastQty': '1.19900000',
#    'bidPrice': '0.07338500',
#    'bidQty': '17.02570000',
#    'askPrice': '0.07338600',
#    'askQty': '23.84750000',
#    'openPrice': '0.07448200',
#    'highPrice': '0.07455500',
#    'lowPrice': '0.07302300',
#    'volume': '67544.74320000',
#    'quoteVolume': '4992.01943775',
#    'openTime': '1674023314305',
#    'closeTime': '1674109714305',
#    'firstId': '398109913',
#    'lastId': '398242139',
#    'count': '132227'}},
#  'LTC/BTC': {'symbol': 'LTC/BTC',
#   'timestamp': 1674109715017,
#   'datetime': '2023-01-19T06:28:35.017Z',
#   'high': 0.004145,
#   'low': 0.003961,
#   'bid': 0.004013,
#   'bidVolume': 2.955,
#   'ask': 0.004014,
#   'askVolume': 94.067,
#   'vwap': 0.00404067,
#   'open': 0.004122,
#   'close': 0.004013,
#   'last': 0.004013,
#   'previousClose': 0.004122,
#   'change': -0.000109,
#   'percentage': -2.644,
#   'average': 0.0040675,
#   'baseVolume': 96423.257,
#   'quoteVolume': 389.61433238,
#   'info': {'symbol': 'LTCBTC',
#    'priceChange': '-0.00010900',
#    'priceChangePercent': '-2.644',
#    'weightedAvgPrice': '0.00404067',
#    'prevClosePrice': '0.00412200',
#    'lastPrice': '0.00401300',
#    'lastQty': '0.91900000',
#    'bidPrice': '0.00401300',
#    'bidQty': '2.95500000',
#    'askPrice': '0.00401400',
#    'askQty': '94.06700000',
#    'openPrice': '0.00412200',
#    'highPrice': '0.00414500',
#    'lowPrice': '0.00396100',
#    'volume': '96423.25700000',
#    'quoteVolume': '389.61433238',
#    'openTime': '1674023315017',
#    'closeTime': '1674109715017',
#    'firstId': '87668040',
#    'lastId': '87696290',
#    'count': '28251'}},
#  'BNB/BTC': {'symbol': 'BNB/BTC',
#   'timestamp': 1674109718486,
#   'datetime': '2023-01-19T06:28:38.486Z',
#   'high': 0.014231,
#   'low': 0.013679,
#   'bid': 0.013922,
#   'bidVolume': 9.067,
#   'ask': 0.013923,
#   'askVolume': 3.369,
#   'vwap': 0.01397472,
#   'open': 0.014231,
#   'close': 0.013922,
#   'last': 0.013922,
#   'previousClose': 0.014231,
#   'change': -0.000309,
#   'percentage': -2.171,
#   'average': 0.0140765,
#   'baseVolume': 49400.627,
#   'quoteVolume': 690.35974695,
#   'info': {'symbol': 'BNBBTC',
#    'priceChange': '-0.00030900',
#    'priceChangePercent': '-2.171',
#    'weightedAvgPrice': '0.01397472',
#    'prevClosePrice': '0.01423100',
#    'lastPrice': '0.01392200',
#    'lastQty': '0.01500000',
#    'bidPrice': '0.01392200',
#    'bidQty': '9.06700000',
#    'askPrice': '0.01392300',
#    'askQty': '3.36900000',
#    'openPrice': '0.01423100',
#    'highPrice': '0.01423100',
#    'lowPrice': '0.01367900',
#    'volume': '49400.62700000',
#    'quoteVolume': '690.35974695',
#    'openTime': '1674023318486',
#    'closeTime': '1674109718486',
#    'firstId': '214209895',
#    'lastId': '214281551',
#    'count': '71657'}},
#  'NEO/BTC': {'symbol': 'NEO/BTC',
#   'timestamp': 1674109719239,
#   'datetime': '2023-01-19T06:28:39.239Z',
#   'high': 0.000364,
#   'low': 0.000344,
#   'bid': 0.000349,
#   'bidVolume': 671.57,
#   'ask': 0.00035,
#   'askVolume': 677.48,
#   'vwap': 0.00035239,
#   'open': 0.000363,
#   'close': 0.00035,
#   'last': 0.00035,
#   'previousClose': 0.000363,
#   'change': -1.3e-05,
#   'percentage': -3.581,
#   'average': 0.0003565,
#   'baseVolume': 41916.64,
#   'quoteVolume': 14.7708555,
#   'info': {'symbol': 'NEOBTC',
#    'priceChange': '-0.00001300',
#    'priceChangePercent': '-3.581',
#    'weightedAvgPrice': '0.00035239',
#    'prevClosePrice': '0.00036300',
#    'lastPrice': '0.00035000',
#    'lastQty': '83.17000000',
#    'bidPrice': '0.00034900',
#    'bidQty': '671.57000000',
#    'askPrice': '0.00035000',
#    'askQty': '677.48000000',
#    'openPrice': '0.00036300',
#    'highPrice': '0.00036400',
#    'lowPrice': '0.00034400',
#    'volume': '41916.64000000',
#    'quoteVolume': '14.77085550',
#    'openTime': '1674023319239',
#    'closeTime': '1674109719239',
#    'firstId': '44173144',
#    'lastId': '44175450',
#    'count': '2307'}},
#  'QTUM/ETH': {'symbol': 'QTUM/ETH',
#   'timestamp': 1674109710463,
#   'datetime': '2023-01-19T06:28:30.463Z',
#   'high': 0.001516,
#   'low': 0.001448,
#   'bid': 0.001476,
#   'bidVolume': 155.4,
#   'ask': 0.001482,
#   'askVolume': 206.7,
#   'vwap': 0.00147965,
#   'open': 0.001501,
#   'close': 0.001481,
#   'last': 0.001481,
#   'previousClose': 0.001497,
#   'change': -2e-05,
#   'percentage': -1.332,
#   'average': 0.001491,
#   'baseVolume': 2887.7,
#   'quoteVolume': 4.272796,
#   'info': {'symbol': 'QTUMETH',
#    'priceChange': '-0.00002000',
#    'priceChangePercent': '-1.332',
#    'weightedAvgPrice': '0.00147965',
#    'prevClosePrice': '0.00149700',
#    'lastPrice': '0.00148100',
#    'lastQty': '4.00000000',
#    'bidPrice': '0.00147600',
#    'bidQty': '155.40000000',
#    'askPrice': '0.00148200',
#    'askQty': '206.70000000',
#    'openPrice': '0.00150100',
#    'highPrice': '0.00151600',
#    'lowPrice': '0.00144800',
#    'volume': '2887.70000000',
#    'quoteVolume': '4.27279600',
#    'openTime': '1674023310463',
#    'closeTime': '1674109710463',
#    'firstId': '5352065',
#    'lastId': '5352162',
#    'count': '98'}},
#  'EOS/ETH': {'symbol': 'EOS/ETH',
#   'timestamp': 1674109717435,
#   'datetime': '2023-01-19T06:28:37.435Z',
#   'high': 0.000654,
#   'low': 0.000607,
#   'bid': 0.000633,
#   'bidVolume': 3019.2,
#   'ask': 0.000635,
#   'askVolume': 62.9,
#   'vwap': 0.00063196,
#   'open': 0.000653,
#   'close': 0.000633,
#   'last': 0.000633,
#   'previousClose': 0.000652,
#   'change': -2e-05,
#   'percentage': -3.063,
#   'average': 0.000643,
#   'baseVolume': 77204.4,
#   'quoteVolume': 48.789913,
#   'info': {'symbol': 'EOSETH',
#    'priceChange': '-0.00002000',
#    'priceChangePercent': '-3.063',
#    'weightedAvgPrice': '0.00063196',
#    'prevClosePrice': '0.00065200',
#    'lastPrice': '0.00063300',
#    'lastQty': '8.40000000',
#    'bidPrice': '0.00063300',
#    'bidQty': '3019.20000000',
#    'askPrice': '0.00063500',
#    'askQty': '62.90000000',
#    'openPrice': '0.00065300',
#    'highPrice': '0.00065400',
#    'lowPrice': '0.00060700',
#    'volume': '77204.40000000',
#    'quoteVolume': '48.78991300',
#    'openTime': '1674023317435',
#    'closeTime': '1674109717435',
#    'firstId': '23382335',
#    'lastId': '23382983',
#    'count': '649'}},
#  'SNT/ETH': {'symbol': 'SNT/ETH',
#   'timestamp': 1674109651434,
#   'datetime': '2023-01-19T06:27:31.434Z',
#   'high': 1.642e-05,
#   'low': 1.518e-05,
#   'bid': 1.532e-05,
#   'bidVolume': 25165.0,
#   'ask': 1.541e-05,
#   'askVolume': 510.0,
#   'vwap': 1.575e-05,
#   'open': 1.563e-05,
#   'close': 1.538e-05,
#   'last': 1.538e-05,
#   'previousClose': 1.566e-05,
#   'change': -2.5e-07,
#   'percentage': -1.599,
#   'average': 1.5505e-05,
#   'baseVolume': 10105851.0,
#   'quoteVolume': 159.15296224,
#   'info': {'symbol': 'SNTETH',
#    'priceChange': '-0.00000025',
#    'priceChangePercent': '-1.599',
#    'weightedAvgPrice': '0.00001575',
#    'prevClosePrice': '0.00001566',
#    'lastPrice': '0.00001538',
#    'lastQty': '593.00000000',
#    'bidPrice': '0.00001532',
#    'bidQty': '25165.00000000',
#    'askPrice': '0.00001541',
#    'askQty': '510.00000000',
#    'openPrice': '0.00001563',
#    'highPrice': '0.00001642',
#    'lowPrice': '0.00001518',
#    'volume': '10105851.00000000',
#    'quoteVolume': '159.15296224',
#    'openTime': '1674023251434',
#    'closeTime': '1674109651434',
#    'firstId': '3793509',
#    'lastId': '3794616',
#    'count': '1108'}},
#  'BNT/ETH': {'symbol': 'BNT/ETH',
#   'timestamp': 1674109646429,
#   'datetime': '2023-01-19T06:27:26.429Z',
#   'high': 0.000261,
#   'low': 0.000247,
#   'bid': 0.000249,
#   'bidVolume': 506.4,
#   'ask': 0.000251,
#   'askVolume': 1868.5,
#   'vwap': 0.0002555,
#   'open': 0.000259,
#   'close': 0.00025,
#   'last': 0.00025,
#   'previousClose': 0.00026,
#   'change': -9e-06,
#   'percentage': -3.475,
#   'average': 0.0002545,
#   'baseVolume': 39429.4,
#   'quoteVolume': 10.0740265,
#   'info': {'symbol': 'BNTETH',
#    'priceChange': '-0.00000900',
#    'priceChangePercent': '-3.475',
#    'weightedAvgPrice': '0.00025550',
#    'prevClosePrice': '0.00026000',
#    'lastPrice': '0.00025000',
#    'lastQty': '20.20000000',
#    'bidPrice': '0.00024900',
#    'bidQty': '506.40000000',
#    'askPrice': '0.00025100',
#    'askQty': '1868.50000000',
#    'openPrice': '0.00025900',
#    'highPrice': '0.00026100',
#    'lowPrice': '0.00024700',
#    'volume': '39429.40000000',
#    'quoteVolume': '10.07402650',
#    'openTime': '1674023246429',
#    'closeTime': '1674109646429',
#    'firstId': '2177637',
#    'lastId': '2177841',
#    'count': '205'}},
#  'BCC/BTC': {'symbol': 'BCC/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.079081,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'BCCBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.07908100',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'GAS/BTC': {'symbol': 'GAS/BTC',
#   'timestamp': 1674108876458,
#   'datetime': '2023-01-19T06:14:36.458Z',
#   'high': 0.0001155,
#   'low': 0.0001101,
#   'bid': 0.0001137,
#   'bidVolume': 19.2,
#   'ask': 0.0001139,
#   'askVolume': 27.0,
#   'vwap': 0.00011317,
#   'open': 0.0001155,
#   'close': 0.0001138,
#   'last': 0.0001138,
#   'previousClose': 0.0001155,
#   'change': -1.7e-06,
#   'percentage': -1.472,
#   'average': 0.00011465,
#   'baseVolume': 93312.0,
#   'quoteVolume': 10.56039729,
#   'info': {'symbol': 'GASBTC',
#    'priceChange': '-0.00000170',
#    'priceChangePercent': '-1.472',
#    'weightedAvgPrice': '0.00011317',
#    'prevClosePrice': '0.00011550',
#    'lastPrice': '0.00011380',
#    'lastQty': '157.10000000',
#    'bidPrice': '0.00011370',
#    'bidQty': '19.20000000',
#    'askPrice': '0.00011390',
#    'askQty': '27.00000000',
#    'openPrice': '0.00011550',
#    'highPrice': '0.00011550',
#    'lowPrice': '0.00011010',
#    'volume': '93312.00000000',
#    'quoteVolume': '10.56039729',
#    'openTime': '1674022476458',
#    'closeTime': '1674108876458',
#    'firstId': '19850723',
#    'lastId': '19854454',
#    'count': '3732'}},
#  'BNB/ETH': {'symbol': 'BNB/ETH',
#   'timestamp': 1674109708370,
#   'datetime': '2023-01-19T06:28:28.370Z',
#   'high': 0.1913,
#   'low': 0.1851,
#   'bid': 0.1897,
#   'bidVolume': 5.703,
#   'ask': 0.1898,
#   'askVolume': 0.281,
#   'vwap': 0.18926833,
#   'open': 0.1911,
#   'close': 0.1898,
#   'last': 0.1898,
#   'previousClose': 0.191,
#   'change': -0.0013,
#   'percentage': -0.68,
#   'average': 0.19045,
#   'baseVolume': 22886.306,
#   'quoteVolume': 4331.6528573,
#   'info': {'symbol': 'BNBETH',
#    'priceChange': '-0.00130000',
#    'priceChangePercent': '-0.680',
#    'weightedAvgPrice': '0.18926833',
#    'prevClosePrice': '0.19100000',
#    'lastPrice': '0.18980000',
#    'lastQty': '0.40900000',
#    'bidPrice': '0.18970000',
#    'bidQty': '5.70300000',
#    'askPrice': '0.18980000',
#    'askQty': '0.28100000',
#    'openPrice': '0.19110000',
#    'highPrice': '0.19130000',
#    'lowPrice': '0.18510000',
#    'volume': '22886.30600000',
#    'quoteVolume': '4331.65285730',
#    'openTime': '1674023308370',
#    'closeTime': '1674109708370',
#    'firstId': '53336967',
#    'lastId': '53353917',
#    'count': '16951'}},
#  'BTC/USDT': {'symbol': 'BTC/USDT',
#   'timestamp': 1674109719750,
#   'datetime': '2023-01-19T06:28:39.750Z',
#   'high': 21650.0,
#   'low': 20407.15,
#   'bid': 20829.59,
#   'bidVolume': 0.07682,
#   'ask': 20829.76,
#   'askVolume': 0.003,
#   'vwap': 21008.50120061,
#   'open': 21276.5,
#   'close': 20829.63,
#   'last': 20829.63,
#   'previousClose': 21276.67,
#   'change': -446.87,
#   'percentage': -2.1,
#   'average': 21053.065,
#   'baseVolume': 349620.16409,
#   'quoteVolume': 7344995637.043821,
#   'info': {'symbol': 'BTCUSDT',
#    'priceChange': '-446.87000000',
#    'priceChangePercent': '-2.100',
#    'weightedAvgPrice': '21008.50120061',
#    'prevClosePrice': '21276.67000000',
#    'lastPrice': '20829.63000000',
#    'lastQty': '0.04178000',
#    'bidPrice': '20829.59000000',
#    'bidQty': '0.07682000',
#    'askPrice': '20829.76000000',
#    'askQty': '0.00300000',
#    'openPrice': '21276.50000000',
#    'highPrice': '21650.00000000',
#    'lowPrice': '20407.15000000',
#    'volume': '349620.16409000',
#    'quoteVolume': '7344995637.04382110',
#    'openTime': '1674023319750',
#    'closeTime': '1674109719750',
#    'firstId': '2507358376',
#    'lastId': '2514906197',
#    'count': '7547822'}},
#  'ETH/USDT': {'symbol': 'ETH/USDT',
#   'timestamp': 1674109719703,
#   'datetime': '2023-01-19T06:28:39.703Z',
#   'high': 1610.0,
#   'low': 1501.39,
#   'bid': 1528.89,
#   'bidVolume': 6.0594,
#   'ask': 1528.9,
#   'askVolume': 34.7328,
#   'vwap': 1551.51884831,
#   'open': 1584.75,
#   'close': 1528.89,
#   'last': 1528.89,
#   'previousClose': 1584.75,
#   'change': -55.86,
#   'percentage': -3.525,
#   'average': 1556.82,
#   'baseVolume': 711023.5797,
#   'quoteVolume': 1103166485.494539,
#   'info': {'symbol': 'ETHUSDT',
#    'priceChange': '-55.86000000',
#    'priceChangePercent': '-3.525',
#    'weightedAvgPrice': '1551.51884831',
#    'prevClosePrice': '1584.75000000',
#    'lastPrice': '1528.89000000',
#    'lastQty': '0.22840000',
#    'bidPrice': '1528.89000000',
#    'bidQty': '6.05940000',
#    'askPrice': '1528.90000000',
#    'askQty': '34.73280000',
#    'openPrice': '1584.75000000',
#    'highPrice': '1610.00000000',
#    'lowPrice': '1501.39000000',
#    'volume': '711023.57970000',
#    'quoteVolume': '1103166485.49453900',
#    'openTime': '1674023319703',
#    'closeTime': '1674109719703',
#    'firstId': '1058961682',
#    'lastId': '1059837875',
#    'count': '876194'}},
#  'HSR/BTC': {'symbol': 'HSR/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.000414,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'HSRBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00041400',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'OAX/ETH': {'symbol': 'OAX/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.0001778,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'OAXETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00017780',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'DNT/ETH': {'symbol': 'DNT/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 2.801e-05,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'DNTETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00002801',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'MCO/ETH': {'symbol': 'MCO/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.005772,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'MCOETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00577200',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'ICN/ETH': {'symbol': 'ICN/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.001663,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'ICNETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00166300',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'MCO/BTC': {'symbol': 'MCO/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.0002114,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'MCOBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00021140',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'WTC/BTC': {'symbol': 'WTC/BTC',
#   'timestamp': 1674109665538,
#   'datetime': '2023-01-19T06:27:45.538Z',
#   'high': 1.027e-05,
#   'low': 9.77e-06,
#   'bid': 9.83e-06,
#   'bidVolume': 823.0,
#   'ask': 9.89e-06,
#   'askVolume': 235.0,
#   'vwap': 9.96e-06,
#   'open': 1.026e-05,
#   'close': 9.87e-06,
#   'last': 9.87e-06,
#   'previousClose': 1.022e-05,
#   'change': -3.9e-07,
#   'percentage': -3.801,
#   'average': 1.0065e-05,
#   'baseVolume': 191584.0,
#   'quoteVolume': 1.90848558,
#   'info': {'symbol': 'WTCBTC',
#    'priceChange': '-0.00000039',
#    'priceChangePercent': '-3.801',
#    'weightedAvgPrice': '0.00000996',
#    'prevClosePrice': '0.00001022',
#    'lastPrice': '0.00000987',
#    'lastQty': '97.00000000',
#    'bidPrice': '0.00000983',
#    'bidQty': '823.00000000',
#    'askPrice': '0.00000989',
#    'askQty': '235.00000000',
#    'openPrice': '0.00001026',
#    'highPrice': '0.00001027',
#    'lowPrice': '0.00000977',
#    'volume': '191584.00000000',
#    'quoteVolume': '1.90848558',
#    'openTime': '1674023265538',
#    'closeTime': '1674109665538',
#    'firstId': '19837159',
#    'lastId': '19837625',
#    'count': '467'}},
#  'WTC/ETH': {'symbol': 'WTC/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.000237,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'WTCETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00023700',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'LRC/BTC': {'symbol': 'LRC/BTC',
#   'timestamp': 1674109716757,
#   'datetime': '2023-01-19T06:28:36.757Z',
#   'high': 1.327e-05,
#   'low': 1.213e-05,
#   'bid': 1.226e-05,
#   'bidVolume': 1646.0,
#   'ask': 1.227e-05,
#   'askVolume': 4356.0,
#   'vwap': 1.262e-05,
#   'open': 1.327e-05,
#   'close': 1.227e-05,
#   'last': 1.227e-05,
#   'previousClose': 1.328e-05,
#   'change': -1e-06,
#   'percentage': -7.536,
#   'average': 1.277e-05,
#   'baseVolume': 1914439.0,
#   'quoteVolume': 24.16461711,
#   'info': {'symbol': 'LRCBTC',
#    'priceChange': '-0.00000100',
#    'priceChangePercent': '-7.536',
#    'weightedAvgPrice': '0.00001262',
#    'prevClosePrice': '0.00001328',
#    'lastPrice': '0.00001227',
#    'lastQty': '81.00000000',
#    'bidPrice': '0.00001226',
#    'bidQty': '1646.00000000',
#    'askPrice': '0.00001227',
#    'askQty': '4356.00000000',
#    'openPrice': '0.00001327',
#    'highPrice': '0.00001327',
#    'lowPrice': '0.00001213',
#    'volume': '1914439.00000000',
#    'quoteVolume': '24.16461711',
#    'openTime': '1674023316757',
#    'closeTime': '1674109716757',
#    'firstId': '21484959',
#    'lastId': '21489569',
#    'count': '4611'}},
#  'LRC/ETH': {'symbol': 'LRC/ETH',
#   'timestamp': 1674109705425,
#   'datetime': '2023-01-19T06:28:25.425Z',
#   'high': 0.0001781,
#   'low': 0.00016541,
#   'bid': 0.00016677,
#   'bidVolume': 8840.0,
#   'ask': 0.00016798,
#   'askVolume': 1961.0,
#   'vwap': 0.00017092,
#   'open': 0.0001781,
#   'close': 0.00016664,
#   'last': 0.00016664,
#   'previousClose': 0.00017829,
#   'change': -1.146e-05,
#   'percentage': -6.435,
#   'average': 0.00017237,
#   'baseVolume': 476634.0,
#   'quoteVolume': 81.46539225,
#   'info': {'symbol': 'LRCETH',
#    'priceChange': '-0.00001146',
#    'priceChangePercent': '-6.435',
#    'weightedAvgPrice': '0.00017092',
#    'prevClosePrice': '0.00017829',
#    'lastPrice': '0.00016664',
#    'lastQty': '713.00000000',
#    'bidPrice': '0.00016677',
#    'bidQty': '8840.00000000',
#    'askPrice': '0.00016798',
#    'askQty': '1961.00000000',
#    'openPrice': '0.00017810',
#    'highPrice': '0.00017810',
#    'lowPrice': '0.00016541',
#    'volume': '476634.00000000',
#    'quoteVolume': '81.46539225',
#    'openTime': '1674023305425',
#    'closeTime': '1674109705425',
#    'firstId': '4636229',
#    'lastId': '4636876',
#    'count': '648'}},
#  'QTUM/BTC': {'symbol': 'QTUM/BTC',
#   'timestamp': 1674109717452,
#   'datetime': '2023-01-19T06:28:37.452Z',
#   'high': 0.0001126,
#   'low': 0.0001065,
#   'bid': 0.0001085,
#   'bidVolume': 351.3,
#   'ask': 0.0001088,
#   'askVolume': 12.0,
#   'vwap': 0.00010922,
#   'open': 0.000112,
#   'close': 0.0001085,
#   'last': 0.0001085,
#   'previousClose': 0.0001118,
#   'change': -3.5e-06,
#   'percentage': -3.125,
#   'average': 0.00011025,
#   'baseVolume': 94628.5,
#   'quoteVolume': 10.33537495,
#   'info': {'symbol': 'QTUMBTC',
#    'priceChange': '-0.00000350',
#    'priceChangePercent': '-3.125',
#    'weightedAvgPrice': '0.00010922',
#    'prevClosePrice': '0.00011180',
#    'lastPrice': '0.00010850',
#    'lastQty': '90.50000000',
#    'bidPrice': '0.00010850',
#    'bidQty': '351.30000000',
#    'askPrice': '0.00010880',
#    'askQty': '12.00000000',
#    'openPrice': '0.00011200',
#    'highPrice': '0.00011260',
#    'lowPrice': '0.00010650',
#    'volume': '94628.50000000',
#    'quoteVolume': '10.33537495',
#    'openTime': '1674023317452',
#    'closeTime': '1674109717452',
#    'firstId': '23671430',
#    'lastId': '23677231',
#    'count': '5802'}},
#  'YOYOW/BTC': {'symbol': 'YOYOW/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 8e-08,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'YOYOBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00000008',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'OMG/BTC': {'symbol': 'OMG/BTC',
#   'timestamp': 1674109717622,
#   'datetime': '2023-01-19T06:28:37.622Z',
#   'high': 6.11e-05,
#   'low': 5.73e-05,
#   'bid': 5.86e-05,
#   'bidVolume': 1637.3,
#   'ask': 5.88e-05,
#   'askVolume': 901.1,
#   'vwap': 5.903e-05,
#   'open': 6.1e-05,
#   'close': 5.88e-05,
#   'last': 5.88e-05,
#   'previousClose': 6.09e-05,
#   'change': -2.2e-06,
#   'percentage': -3.607,
#   'average': 5.99e-05,
#   'baseVolume': 55033.3,
#   'quoteVolume': 3.24873953,
#   'info': {'symbol': 'OMGBTC',
#    'priceChange': '-0.00000220',
#    'priceChangePercent': '-3.607',
#    'weightedAvgPrice': '0.00005903',
#    'prevClosePrice': '0.00006090',
#    'lastPrice': '0.00005880',
#    'lastQty': '158.40000000',
#    'bidPrice': '0.00005860',
#    'bidQty': '1637.30000000',
#    'askPrice': '0.00005880',
#    'askQty': '901.10000000',
#    'openPrice': '0.00006100',
#    'highPrice': '0.00006110',
#    'lowPrice': '0.00005730',
#    'volume': '55033.30000000',
#    'quoteVolume': '3.24873953',
#    'openTime': '1674023317622',
#    'closeTime': '1674109717622',
#    'firstId': '25955441',
#    'lastId': '25957290',
#    'count': '1850'}},
#  'OMG/ETH': {'symbol': 'OMG/ETH',
#   'timestamp': 1674109717588,
#   'datetime': '2023-01-19T06:28:37.588Z',
#   'high': 0.000819,
#   'low': 0.000784,
#   'bid': 0.000798,
#   'bidVolume': 537.0,
#   'ask': 0.000802,
#   'askVolume': 145.1,
#   'vwap': 0.00079776,
#   'open': 0.000817,
#   'close': 0.000795,
#   'last': 0.000795,
#   'previousClose': 0.00082,
#   'change': -2.2e-05,
#   'percentage': -2.693,
#   'average': 0.000806,
#   'baseVolume': 6238.6,
#   'quoteVolume': 4.9768998,
#   'info': {'symbol': 'OMGETH',
#    'priceChange': '-0.00002200',
#    'priceChangePercent': '-2.693',
#    'weightedAvgPrice': '0.00079776',
#    'prevClosePrice': '0.00082000',
#    'lastPrice': '0.00079500',
#    'lastQty': '22.20000000',
#    'bidPrice': '0.00079800',
#    'bidQty': '537.00000000',
#    'askPrice': '0.00080200',
#    'askQty': '145.10000000',
#    'openPrice': '0.00081700',
#    'highPrice': '0.00081900',
#    'lowPrice': '0.00078400',
#    'volume': '6238.60000000',
#    'quoteVolume': '4.97689980',
#    'openTime': '1674023317588',
#    'closeTime': '1674109717588',
#    'firstId': '5873965',
#    'lastId': '5874050',
#    'count': '86'}},
#  'ZRX/BTC': {'symbol': 'ZRX/BTC',
#   'timestamp': 1674109712528,
#   'datetime': '2023-01-19T06:28:32.528Z',
#   'high': 1.048e-05,
#   'low': 9.5e-06,
#   'bid': 9.73e-06,
#   'bidVolume': 6911.0,
#   'ask': 9.79e-06,
#   'askVolume': 28.0,
#   'vwap': 9.96e-06,
#   'open': 1.008e-05,
#   'close': 9.73e-06,
#   'last': 9.73e-06,
#   'previousClose': 1.008e-05,
#   'change': -3.5e-07,
#   'percentage': -3.472,
#   'average': 9.905e-06,
#   'baseVolume': 1092220.0,
#   'quoteVolume': 10.87902668,
#   'info': {'symbol': 'ZRXBTC',
#    'priceChange': '-0.00000035',
#    'priceChangePercent': '-3.472',
#    'weightedAvgPrice': '0.00000996',
#    'prevClosePrice': '0.00001008',
#    'lastPrice': '0.00000973',
#    'lastQty': '492.00000000',
#    'bidPrice': '0.00000973',
#    'bidQty': '6911.00000000',
#    'askPrice': '0.00000979',
#    'askQty': '28.00000000',
#    'openPrice': '0.00001008',
#    'highPrice': '0.00001048',
#    'lowPrice': '0.00000950',
#    'volume': '1092220.00000000',
#    'quoteVolume': '10.87902668',
#    'openTime': '1674023312528',
#    'closeTime': '1674109712528',
#    'firstId': '25058404',
#    'lastId': '25062316',
#    'count': '3913'}},
#  'ZRX/ETH': {'symbol': 'ZRX/ETH',
#   'timestamp': 1674109678600,
#   'datetime': '2023-01-19T06:27:58.600Z',
#   'high': 0.000143,
#   'low': 0.0001302,
#   'bid': 0.0001327,
#   'bidVolume': 307.0,
#   'ask': 0.0001339,
#   'askVolume': 45.0,
#   'vwap': 0.00013435,
#   'open': 0.0001345,
#   'close': 0.0001325,
#   'last': 0.0001325,
#   'previousClose': 0.0001346,
#   'change': -2e-06,
#   'percentage': -1.487,
#   'average': 0.0001335,
#   'baseVolume': 233550.0,
#   'quoteVolume': 31.3786011,
#   'info': {'symbol': 'ZRXETH',
#    'priceChange': '-0.00000200',
#    'priceChangePercent': '-1.487',
#    'weightedAvgPrice': '0.00013435',
#    'prevClosePrice': '0.00013460',
#    'lastPrice': '0.00013250',
#    'lastQty': '52.00000000',
#    'bidPrice': '0.00013270',
#    'bidQty': '307.00000000',
#    'askPrice': '0.00013390',
#    'askQty': '45.00000000',
#    'openPrice': '0.00013450',
#    'highPrice': '0.00014300',
#    'lowPrice': '0.00013020',
#    'volume': '233550.00000000',
#    'quoteVolume': '31.37860110',
#    'openTime': '1674023278600',
#    'closeTime': '1674109678600',
#    'firstId': '5342551',
#    'lastId': '5343108',
#    'count': '558'}},
#  'STRAT/BTC': {'symbol': 'STRAT/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 3.085e-05,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'STRATBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00003085',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'STRAT/ETH': {'symbol': 'STRAT/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.001053,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'STRATETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00105300',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'SNGLS/BTC': {'symbol': 'SNGLS/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 1.3e-07,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'SNGLSBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00000013',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'SNGLS/ETH': {'symbol': 'SNGLS/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 5.306e-05,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'SNGLSETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00005306',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'BQX/BTC': {'symbol': 'BQX/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 8.703e-05,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'BQXBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00008703',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'BQX/ETH': {'symbol': 'BQX/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.0012635,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'BQXETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00126350',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'KNC/BTC': {'symbol': 'KNC/BTC',
#   'timestamp': 1674109708197,
#   'datetime': '2023-01-19T06:28:28.197Z',
#   'high': 3.712e-05,
#   'low': 3.25e-05,
#   'bid': 3.6e-05,
#   'bidVolume': 805.3,
#   'ask': 3.606e-05,
#   'askVolume': 806.2,
#   'vwap': 3.543e-05,
#   'open': 3.5e-05,
#   'close': 3.601e-05,
#   'last': 3.601e-05,
#   'previousClose': 3.494e-05,
#   'change': 1.01e-06,
#   'percentage': 2.886,
#   'average': 3.5505e-05,
#   'baseVolume': 1157376.4,
#   'quoteVolume': 41.00234197,
#   'info': {'symbol': 'KNCBTC',
#    'priceChange': '0.00000101',
#    'priceChangePercent': '2.886',
#    'weightedAvgPrice': '0.00003543',
#    'prevClosePrice': '0.00003494',
#    'lastPrice': '0.00003601',
#    'lastQty': '46.40000000',
#    'bidPrice': '0.00003600',
#    'bidQty': '805.30000000',
#    'askPrice': '0.00003606',
#    'askQty': '806.20000000',
#    'openPrice': '0.00003500',
#    'highPrice': '0.00003712',
#    'lowPrice': '0.00003250',
#    'volume': '1157376.40000000',
#    'quoteVolume': '41.00234197',
#    'openTime': '1674023308197',
#    'closeTime': '1674109708197',
#    'firstId': '19726536',
#    'lastId': '19737182',
#    'count': '10647'}},
#  'KNC/ETH': {'symbol': 'KNC/ETH',
#   'timestamp': 1674109659481,
#   'datetime': '2023-01-19T06:27:39.481Z',
#   'high': 0.0005072,
#   'low': 0.0004452,
#   'bid': 0.0004905,
#   'bidVolume': 1332.4,
#   'ask': 0.0004925,
#   'askVolume': 948.9,
#   'vwap': 0.00047579,
#   'open': 0.0004684,
#   'close': 0.0004893,
#   'last': 0.0004893,
#   'previousClose': 0.0004711,
#   'change': 2.09e-05,
#   'percentage': 4.462,
#   'average': 0.00047885,
#   'baseVolume': 146597.3,
#   'quoteVolume': 69.74917415,
#   'info': {'symbol': 'KNCETH',
#    'priceChange': '0.00002090',
#    'priceChangePercent': '4.462',
#    'weightedAvgPrice': '0.00047579',
#    'prevClosePrice': '0.00047110',
#    'lastPrice': '0.00048930',
#    'lastQty': '178.20000000',
#    'bidPrice': '0.00049050',
#    'bidQty': '1332.40000000',
#    'askPrice': '0.00049250',
#    'askQty': '948.90000000',
#    'openPrice': '0.00046840',
#    'highPrice': '0.00050720',
#    'lowPrice': '0.00044520',
#    'volume': '146597.30000000',
#    'quoteVolume': '69.74917415',
#    'openTime': '1674023259481',
#    'closeTime': '1674109659481',
#    'firstId': '4720245',
#    'lastId': '4721822',
#    'count': '1578'}},
#  'FUN/BTC': {'symbol': 'FUN/BTC',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 2.9e-07,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'FUNBTC',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00000029',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'FUN/ETH': {'symbol': 'FUN/ETH',
#   'timestamp': 1674109710034,
#   'datetime': '2023-01-19T06:28:30.034Z',
#   'high': 5.32e-06,
#   'low': 4.4e-06,
#   'bid': 4.57e-06,
#   'bidVolume': 72498.0,
#   'ask': 4.6e-06,
#   'askVolume': 160851.0,
#   'vwap': 4.69e-06,
#   'open': 4.48e-06,
#   'close': 4.58e-06,
#   'last': 4.58e-06,
#   'previousClose': 4.5e-06,
#   'change': 1e-07,
#   'percentage': 2.232,
#   'average': 4.53e-06,
#   'baseVolume': 32380231.0,
#   'quoteVolume': 151.87671481,
#   'info': {'symbol': 'FUNETH',
#    'priceChange': '0.00000010',
#    'priceChangePercent': '2.232',
#    'weightedAvgPrice': '0.00000469',
#    'prevClosePrice': '0.00000450',
#    'lastPrice': '0.00000458',
#    'lastQty': '44680.00000000',
#    'bidPrice': '0.00000457',
#    'bidQty': '72498.00000000',
#    'askPrice': '0.00000460',
#    'askQty': '160851.00000000',
#    'openPrice': '0.00000448',
#    'highPrice': '0.00000532',
#    'lowPrice': '0.00000440',
#    'volume': '32380231.00000000',
#    'quoteVolume': '151.87671481',
#    'openTime': '1674023310034',
#    'closeTime': '1674109710034',
#    'firstId': '3119688',
#    'lastId': '3121119',
#    'count': '1432'}},
#  'SNM/BTC': {'symbol': 'SNM/BTC',
#   'timestamp': 1674109716282,
#   'datetime': '2023-01-19T06:28:36.282Z',
#   'high': 2.742e-05,
#   'low': 2.482e-05,
#   'bid': 2.535e-05,
#   'bidVolume': 59.0,
#   'ask': 2.542e-05,
#   'askVolume': 89.0,
#   'vwap': 2.61e-05,
#   'open': 2.731e-05,
#   'close': 2.532e-05,
#   'last': 2.532e-05,
#   'previousClose': 2.728e-05,
#   'change': -1.99e-06,
#   'percentage': -7.287,
#   'average': 2.6315e-05,
#   'baseVolume': 672979.0,
#   'quoteVolume': 17.5624242,
#   'info': {'symbol': 'SNMBTC',
#    'priceChange': '-0.00000199',
#    'priceChangePercent': '-7.287',
#    'weightedAvgPrice': '0.00002610',
#    'prevClosePrice': '0.00002728',
#    'lastPrice': '0.00002532',
#    'lastQty': '148.00000000',
#    'bidPrice': '0.00002535',
#    'bidQty': '59.00000000',
#    'askPrice': '0.00002542',
#    'askQty': '89.00000000',
#    'openPrice': '0.00002731',
#    'highPrice': '0.00002742',
#    'lowPrice': '0.00002482',
#    'volume': '672979.00000000',
#    'quoteVolume': '17.56242420',
#    'openTime': '1674023316282',
#    'closeTime': '1674109716282',
#    'firstId': '13202395',
#    'lastId': '13206219',
#    'count': '3825'}},
#  'SNM/ETH': {'symbol': 'SNM/ETH',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 4.986e-05,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'SNMETH',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00004986',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'NEO/ETH': {'symbol': 'NEO/ETH',
#   'timestamp': 1674109719153,
#   'datetime': '2023-01-19T06:28:39.153Z',
#   'high': 0.00489,
#   'low': 0.00469,
#   'bid': 0.00476,
#   'bidVolume': 96.14,
#   'ask': 0.00477,
#   'askVolume': 65.92,
#   'vwap': 0.00479279,
#   'open': 0.00487,
#   'close': 0.00478,
#   'last': 0.00478,
#   'previousClose': 0.00487,
#   'change': -9e-05,
#   'percentage': -1.848,
#   'average': 0.004825,
#   'baseVolume': 7929.31,
#   'quoteVolume': 38.0035035,
#   'info': {'symbol': 'NEOETH',
#    'priceChange': '-0.00009000',
#    'priceChangePercent': '-1.848',
#    'weightedAvgPrice': '0.00479279',
#    'prevClosePrice': '0.00487000',
#    'lastPrice': '0.00478000',
#    'lastQty': '37.74000000',
#    'bidPrice': '0.00476000',
#    'bidQty': '96.14000000',
#    'askPrice': '0.00477000',
#    'askQty': '65.92000000',
#    'openPrice': '0.00487000',
#    'highPrice': '0.00489000',
#    'lowPrice': '0.00469000',
#    'volume': '7929.31000000',
#    'quoteVolume': '38.00350350',
#    'openTime': '1674023319153',
#    'closeTime': '1674109719153',
#    'firstId': '11076136',
#    'lastId': '11076878',
#    'count': '743'}},
#  'IOTA/BTC': {'symbol': 'IOTA/BTC',
#   'timestamp': 1674109710641,
#   'datetime': '2023-01-19T06:28:30.641Z',
#   'high': 1.028e-05,
#   'low': 9.67e-06,
#   'bid': 9.74e-06,
#   'bidVolume': 5354.0,
#   'ask': 9.76e-06,
#   'askVolume': 7333.0,
#   'vwap': 9.96e-06,
#   'open': 1.024e-05,
#   'close': 9.74e-06,
#   'last': 9.74e-06,
#   'previousClose': 1.022e-05,
#   'change': -5e-07,
#   'percentage': -4.883,
#   'average': 9.99e-06,
#   'baseVolume': 1382839.0,
#   'quoteVolume': 13.77264701,
#   'info': {'symbol': 'IOTABTC',
#    'priceChange': '-0.00000050',
#    'priceChangePercent': '-4.883',
#    'weightedAvgPrice': '0.00000996',
#    'prevClosePrice': '0.00001022',
#    'lastPrice': '0.00000974',
#    'lastQty': '2636.00000000',
#    'bidPrice': '0.00000974',
#    'bidQty': '5354.00000000',
#    'askPrice': '0.00000976',
#    'askQty': '7333.00000000',
#    'openPrice': '0.00001024',
#    'highPrice': '0.00001028',
#    'lowPrice': '0.00000967',
#    'volume': '1382839.00000000',
#    'quoteVolume': '13.77264701',
#    'openTime': '1674023310641',
#    'closeTime': '1674109710641',
#    'firstId': '33872299',
#    'lastId': '33874851',
#    'count': '2553'}},
#  'IOTA/ETH': {'symbol': 'IOTA/ETH',
#   'timestamp': 1674109708970,
#   'datetime': '2023-01-19T06:28:28.970Z',
#   'high': 0.000138,
#   'low': 0.0001318,
#   'bid': 0.0001326,
#   'bidVolume': 3246.0,
#   'ask': 0.000133,
#   'askVolume': 4051.0,
#   'vwap': 0.00013435,
#   'open': 0.0001376,
#   'close': 0.000133,
#   'last': 0.000133,
#   'previousClose': 0.0001375,
#   'change': -4.6e-06,
#   'percentage': -3.343,
#   'average': 0.0001353,
#   'baseVolume': 119084.0,
#   'quoteVolume': 15.9986663,
#   'info': {'symbol': 'IOTAETH',
#    'priceChange': '-0.00000460',
#    'priceChangePercent': '-3.343',
#    'weightedAvgPrice': '0.00013435',
#    'prevClosePrice': '0.00013750',
#    'lastPrice': '0.00013300',
#    'lastQty': '3037.00000000',
#    'bidPrice': '0.00013260',
#    'bidQty': '3246.00000000',
#    'askPrice': '0.00013300',
#    'askQty': '4051.00000000',
#    'openPrice': '0.00013760',
#    'highPrice': '0.00013800',
#    'lowPrice': '0.00013180',
#    'volume': '119084.00000000',
#    'quoteVolume': '15.99866630',
#    'openTime': '1674023308970',
#    'closeTime': '1674109708970',
#    'firstId': '7737181',
#    'lastId': '7737389',
#    'count': '209'}},
#  'LINK/BTC': {'symbol': 'LINK/BTC',
#   'timestamp': 1674109719025,
#   'datetime': '2023-01-19T06:28:39.025Z',
#   'high': 0.0003236,
#   'low': 0.0003042,
#   'bid': 0.0003086,
#   'bidVolume': 1691.77,
#   'ask': 0.0003087,
#   'askVolume': 61.59,
#   'vwap': 0.00031229,
#   'open': 0.0003235,
#   'close': 0.0003086,
#   'last': 0.0003086,
#   'previousClose': 0.0003235,
#   'change': -1.49e-05,
#   'percentage': -4.606,
#   'average': 0.00031605,
#   'baseVolume': 630959.6,
#   'quoteVolume': 197.04009595,
#   'info': {'symbol': 'LINKBTC',
#    'priceChange': '-0.00001490',
#    'priceChangePercent': '-4.606',
#    'weightedAvgPrice': '0.00031229',
#    'prevClosePrice': '0.00032350',
#    'lastPrice': '0.00030860',
#    'lastQty': '341.68000000',
#    'bidPrice': '0.00030860',
#    'bidQty': '1691.77000000',
#    'askPrice': '0.00030870',
#    'askQty': '61.59000000',
#    'openPrice': '0.00032350',
#    'highPrice': '0.00032360',
#    'lowPrice': '0.00030420',
#    'volume': '630959.60000000',
#    'quoteVolume': '197.04009595',
#    'openTime': '1674023319025',
# ...
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 4.42,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'YFIIBNB',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '4.42000000',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'YFII/BTC': {'symbol': 'YFII/BTC',
#   'timestamp': 1672110071338,
#   'datetime': '2022-12-27T03:01:11.338Z',
#   'high': 0.07295,
#   'low': 0.07199,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.07228323,
#   'open': 0.07264,
#   'close': 0.07249,
#   'last': 0.07249,
#   'previousClose': 0.07258,
#   'change': -0.00015,
#   'percentage': -0.207,
#   'average': 0.072565,
#   'baseVolume': 30.4447,
#   'quoteVolume': 2.20064112,
#   'info': {'symbol': 'YFIIBTC',
#    'priceChange': '-0.00015000',
#    'priceChangePercent': '-0.207',
#    'weightedAvgPrice': '0.07228323',
#    'prevClosePrice': '0.07258000',
#    'lastPrice': '0.07249000',
#    'lastQty': '0.01140000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.07264000',
#    'highPrice': '0.07295000',
#    'lowPrice': '0.07199000',
#    'volume': '30.44470000',
#    'quoteVolume': '2.20064112',
#    'openTime': '1672023671338',
#    'closeTime': '1672110071338',
#    'firstId': '7370006',
#    'lastId': '7370303',
#    'count': '298'}},
#  'YFII/BUSD': {'symbol': 'YFII/BUSD',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 1192.0,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'YFIIBUSD',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '1192.00000000',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'YFII/USDT': {'symbol': 'YFII/USDT',
#   'timestamp': 1674109707190,
#   'datetime': '2023-01-19T06:28:27.190Z',
#   'high': 1365.0,
#   'low': 1200.0,
#   'bid': 1234.7,
#   'bidVolume': 0.2722,
#   'ask': 1235.5,
#   'askVolume': 0.2105,
#   'vwap': 1276.17508335,
#   'open': 1362.5,
#   'close': 1235.6,
#   'last': 1235.6,
#   'previousClose': 1361.6,
#   'change': -126.9,
#   'percentage': -9.314,
#   'average': 1299.05,
#   'baseVolume': 3855.8555,
#   'quoteVolume': 4920746.71409,
#   'info': {'symbol': 'YFIIUSDT',
#    'priceChange': '-126.90000000',
#    'priceChangePercent': '-9.314',
#    'weightedAvgPrice': '1276.17508335',
#    'prevClosePrice': '1361.60000000',
#    'lastPrice': '1235.60000000',
#    'lastQty': '0.17430000',
#    'bidPrice': '1234.70000000',
#    'bidQty': '0.27220000',
#    'askPrice': '1235.50000000',
#    'askQty': '0.21050000',
#    'openPrice': '1362.50000000',
#    'highPrice': '1365.00000000',
#    'lowPrice': '1200.00000000',
#    'volume': '3855.85550000',
#    'quoteVolume': '4920746.71409000',
#    'openTime': '1674023307190',
#    'closeTime': '1674109707190',
#    'firstId': '36043040',
#    'lastId': '36066201',
#    'count': '23162'}},
#  'KSM/BNB': {'symbol': 'KSM/BNB',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.0908,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'KSMBNB',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.09080000',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'KSM/BTC': {'symbol': 'KSM/BTC',
#   'timestamp': 1674109711923,
#   'datetime': '2023-01-19T06:28:31.923Z',
#   'high': 0.001677,
#   'low': 0.001524,
#   'bid': 0.001594,
#   'bidVolume': 6.023,
#   'ask': 0.001595,
#   'askVolume': 1.253,
#   'vwap': 0.00161705,
#   'open': 0.001652,
#   'close': 0.001595,
#   'last': 0.001595,
#   'previousClose': 0.001651,
#   'change': -5.7e-05,
#   'percentage': -3.45,
#   'average': 0.0016235,
#   'baseVolume': 18153.919,
#   'quoteVolume': 29.35573859,
#   'info': {'symbol': 'KSMBTC',
#    'priceChange': '-0.00005700',
#    'priceChangePercent': '-3.450',
#    'weightedAvgPrice': '0.00161705',
#    'prevClosePrice': '0.00165100',
#    'lastPrice': '0.00159500',
#    'lastQty': '13.10600000',
#    'bidPrice': '0.00159400',
#    'bidQty': '6.02300000',
#    'askPrice': '0.00159500',
#    'askQty': '1.25300000',
#    'openPrice': '0.00165200',
#    'highPrice': '0.00167700',
#    'lowPrice': '0.00152400',
#    'volume': '18153.91900000',
#    'quoteVolume': '29.35573859',
#    'openTime': '1674023311923',
#    'closeTime': '1674109711923',
#    'firstId': '9942147',
#    'lastId': '9953276',
#    'count': '11130'}},
#  'KSM/BUSD': {'symbol': 'KSM/BUSD',
#   'timestamp': 1674109716657,
#   'datetime': '2023-01-19T06:28:36.657Z',
#   'high': 35.56,
#   'low': 31.5,
#   'bid': 33.21,
#   'bidVolume': 43.389,
#   'ask': 33.24,
#   'askVolume': 218.444,
#   'vwap': 33.77309117,
#   'open': 35.2,
#   'close': 33.25,
#   'last': 33.25,
#   'previousClose': 35.12,
#   'change': -1.95,
#   'percentage': -5.54,
#   'average': 34.225,
#   'baseVolume': 44821.897,
#   'quoteVolume': 1513774.01364,
#   'info': {'symbol': 'KSMBUSD',
#    'priceChange': '-1.95000000',
#    'priceChangePercent': '-5.540',
#    'weightedAvgPrice': '33.77309117',
#    'prevClosePrice': '35.12000000',
#    'lastPrice': '33.25000000',
#    'lastQty': '2.50200000',
#    'bidPrice': '33.21000000',
#    'bidQty': '43.38900000',
#    'askPrice': '33.24000000',
#    'askQty': '218.44400000',
#    'openPrice': '35.20000000',
#    'highPrice': '35.56000000',
#    'lowPrice': '31.50000000',
#    'volume': '44821.89700000',
#    'quoteVolume': '1513774.01364000',
#    'openTime': '1674023316657',
#    'closeTime': '1674109716657',
#    'firstId': '7499723',
#    'lastId': '7507954',
#    'count': '8232'}},
#  'KSM/USDT': {'symbol': 'KSM/USDT',
#   'timestamp': 1674109717471,
#   'datetime': '2023-01-19T06:28:37.471Z',
#   'high': 35.55,
#   'low': 31.51,
#   'bid': 33.23,
#   'bidVolume': 11.315,
#   'ask': 33.24,
#   'askVolume': 6.015,
#   'vwap': 33.79446232,
#   'open': 35.13,
#   'close': 33.24,
#   'last': 33.24,
#   'previousClose': 35.12,
#   'change': -1.89,
#   'percentage': -5.38,
#   'average': 34.185,
#   'baseVolume': 176702.754,
#   'quoteVolume': 5971574.56132,
#   'info': {'symbol': 'KSMUSDT',
#    'priceChange': '-1.89000000',
#    'priceChangePercent': '-5.380',
#    'weightedAvgPrice': '33.79446232',
#    'prevClosePrice': '35.12000000',
#    'lastPrice': '33.24000000',
#    'lastQty': '24.40100000',
#    'bidPrice': '33.23000000',
#    'bidQty': '11.31500000',
#    'askPrice': '33.24000000',
#    'askQty': '6.01500000',
#    'openPrice': '35.13000000',
#    'highPrice': '35.55000000',
#    'lowPrice': '31.51000000',
#    'volume': '176702.75400000',
#    'quoteVolume': '5971574.56132000',
#    'openTime': '1674023317471',
#    'closeTime': '1674109717471',
#    'firstId': '61167685',
#    'lastId': '61211316',
#    'count': '43632'}},
#  'EGLD/BNB': {'symbol': 'EGLD/BNB',
#   'timestamp': 1674109712095,
#   'datetime': '2023-01-19T06:28:32.095Z',
#   'high': 0.143,
#   'low': 0.1328,
#   'bid': 0.1373,
#   'bidVolume': 8.61,
#   'ask': 0.1376,
#   'askVolume': 16.7,
#   'vwap': 0.1375681,
#   'open': 0.1388,
#   'close': 0.1373,
#   'last': 0.1373,
#   'previousClose': 0.1388,
#   'change': -0.0015,
#   'percentage': -1.081,
#   'average': 0.13805,
#   'baseVolume': 1922.48,
#   'quoteVolume': 264.471929,
#   'info': {'symbol': 'EGLDBNB',
#    'priceChange': '-0.00150000',
#    'priceChangePercent': '-1.081',
#    'weightedAvgPrice': '0.13756810',
#    'prevClosePrice': '0.13880000',
#    'lastPrice': '0.13730000',
#    'lastQty': '7.66000000',
#    'bidPrice': '0.13730000',
#    'bidQty': '8.61000000',
#    'askPrice': '0.13760000',
#    'askQty': '16.70000000',
#    'openPrice': '0.13880000',
#    'highPrice': '0.14300000',
#    'lowPrice': '0.13280000',
#    'volume': '1922.48000000',
#    'quoteVolume': '264.47192900',
#    'openTime': '1674023312095',
#    'closeTime': '1674109712095',
#    'firstId': '2412292',
#    'lastId': '2412877',
#    'count': '586'}},
#  'EGLD/BTC': {'symbol': 'EGLD/BTC',
#   'timestamp': 1674109714366,
#   'datetime': '2023-01-19T06:28:34.366Z',
#   'high': 0.002016,
#   'low': 0.00185,
#   'bid': 0.001914,
#   'bidVolume': 19.01,
#   'ask': 0.001916,
#   'askVolume': 20.3,
#   'vwap': 0.00194102,
#   'open': 0.00197,
#   'close': 0.001916,
#   'last': 0.001916,
#   'previousClose': 0.001971,
#   'change': -5.4e-05,
#   'percentage': -2.741,
#   'average': 0.001943,
#   'baseVolume': 17249.24,
#   'quoteVolume': 33.48107443,
#   'info': {'symbol': 'EGLDBTC',
#    'priceChange': '-0.00005400',
#    'priceChangePercent': '-2.741',
#    'weightedAvgPrice': '0.00194102',
#    'prevClosePrice': '0.00197100',
#    'lastPrice': '0.00191600',
#    'lastQty': '0.08000000',
#    'bidPrice': '0.00191400',
#    'bidQty': '19.01000000',
#    'askPrice': '0.00191600',
#    'askQty': '20.30000000',
#    'openPrice': '0.00197000',
#    'highPrice': '0.00201600',
#    'lowPrice': '0.00185000',
#    'volume': '17249.24000000',
#    'quoteVolume': '33.48107443',
#    'openTime': '1674023314366',
#    'closeTime': '1674109714366',
#    'firstId': '14301050',
#    'lastId': '14307370',
#    'count': '6321'}},
#  'EGLD/BUSD': {'symbol': 'EGLD/BUSD',
#   'timestamp': 1674109708475,
#   'datetime': '2023-01-19T06:28:28.475Z',
#   'high': 43.35,
#   'low': 38.06,
#   'bid': 39.88,
#   'bidVolume': 7.95,
#   'ask': 39.9,
#   'askVolume': 8.18,
#   'vwap': 40.65115563,
#   'open': 41.94,
#   'close': 39.9,
#   'last': 39.9,
#   'previousClose': 41.94,
#   'change': -2.04,
#   'percentage': -4.864,
#   'average': 40.92,
#   'baseVolume': 141763.36,
#   'quoteVolume': 5762844.4103,
#   'info': {'symbol': 'EGLDBUSD',
#    'priceChange': '-2.04000000',
#    'priceChangePercent': '-4.864',
#    'weightedAvgPrice': '40.65115563',
#    'prevClosePrice': '41.94000000',
#    'lastPrice': '39.90000000',
#    'lastQty': '0.27000000',
#    'bidPrice': '39.88000000',
#    'bidQty': '7.95000000',
#    'askPrice': '39.90000000',
#    'askQty': '8.18000000',
#    'openPrice': '41.94000000',
#    'highPrice': '43.35000000',
#    'lowPrice': '38.06000000',
#    'volume': '141763.36000000',
#    'quoteVolume': '5762844.41030000',
#    'openTime': '1674023308475',
#    'closeTime': '1674109708475',
#    'firstId': '18546854',
#    'lastId': '18569949',
#    'count': '23096'}},
#  'EGLD/USDT': {'symbol': 'EGLD/USDT',
#   'timestamp': 1674109719768,
#   'datetime': '2023-01-19T06:28:39.768Z',
#   'high': 43.33,
#   'low': 37.61,
#   'bid': 39.89,
#   'bidVolume': 8.42,
#   'ask': 39.9,
#   'askVolume': 13.9,
#   'vwap': 40.66539019,
#   'open': 41.94,
#   'close': 39.89,
#   'last': 39.89,
#   'previousClose': 41.94,
#   'change': -2.05,
#   'percentage': -4.888,
#   'average': 40.915,
#   'baseVolume': 353258.36,
#   'quoteVolume': 14365389.0464,
#   'info': {'symbol': 'EGLDUSDT',
#    'priceChange': '-2.05000000',
#    'priceChangePercent': '-4.888',
#    'weightedAvgPrice': '40.66539019',
#    'prevClosePrice': '41.94000000',
#    'lastPrice': '39.89000000',
#    'lastQty': '7.66000000',
#    'bidPrice': '39.89000000',
#    'bidQty': '8.42000000',
#    'askPrice': '39.90000000',
#    'askQty': '13.90000000',
#    'openPrice': '41.94000000',
#    'highPrice': '43.33000000',
#    'lowPrice': '37.61000000',
#    'volume': '353258.36000000',
#    'quoteVolume': '14365389.04640000',
#    'openTime': '1674023319768',
#    'closeTime': '1674109719768',
#    'firstId': '80528741',
#    'lastId': '80591573',
#    'count': '62833'}},
#  'DIA/BNB': {'symbol': 'DIA/BNB',
#   'timestamp': 1670907726296,
#   'datetime': '2022-12-13T05:02:06.296Z',
#   'high': 0.0,
#   'low': 0.0,
#   'bid': 0.0,
#   'bidVolume': 0.0,
#   'ask': 0.0,
#   'askVolume': 0.0,
#   'vwap': 0.0,
#   'open': 0.0,
#   'close': 0.0,
#   'last': 0.0,
#   'previousClose': 0.003813,
#   'change': 0.0,
#   'percentage': 0.0,
#   'average': 0.0,
#   'baseVolume': 0.0,
#   'quoteVolume': 0.0,
#   'info': {'symbol': 'DIABNB',
#    'priceChange': '0.00000000',
#    'priceChangePercent': '0.000',
#    'weightedAvgPrice': '0.00000000',
#    'prevClosePrice': '0.00381300',
#    'lastPrice': '0.00000000',
#    'lastQty': '0.00000000',
#    'bidPrice': '0.00000000',
#    'bidQty': '0.00000000',
#    'askPrice': '0.00000000',
#    'askQty': '0.00000000',
#    'openPrice': '0.00000000',
#    'highPrice': '0.00000000',
#    'lowPrice': '0.00000000',
#    'volume': '0.00000000',
#    'quoteVolume': '0.00000000',
#    'openTime': '1670821326296',
#    'closeTime': '1670907726296',
#    'firstId': '-1',
#    'lastId': '-1',
#    'count': '0'}},
#  'DIA/BTC': {'symbol': 'DIA/BTC',
#   'timestamp': 1674109656506,
#   'datetime': '2023-01-19T06:27:36.506Z',
#   'high': 1.605e-05,
#   'low': 1.495e-05,
#   'bid': 1.532e-05,
#   'bidVolume': 123.7,
#   'ask': 1.539e-05,
#   'askVolume': 623.8,
#   'vwap': 1.541e-05,
#   'open': 1.578e-05,
#   'close': 1.532e-05,
#   'last': 1.532e-05,
#   'previousClose': 1.583e-05,
#   'change': -4.6e-07,
#   'percentage': -2.915,
#   'average': 1.555e-05,
#   'baseVolume': 392592.5,
#   'quoteVolume': 6.05175647,
#   'info': {'symbol': 'DIABTC',
#    'priceChange': '-0.00000046',
#    'priceChangePercent': '-2.915',
#    'weightedAvgPrice': '0.00001541',
#    'prevClosePrice': '0.00001583',
#    'lastPrice': '0.00001532',
#    'lastQty': '19.60000000',
#    'bidPrice': '0.00001532',
#    'bidQty': '123.70000000',
#    'askPrice': '0.00001539',
#    'askQty': '623.80000000',
#    'openPrice': '0.00001578',
#    'highPrice': '0.00001605',
#    'lowPrice': '0.00001495',
#    'volume': '392592.50000000',
#    'quoteVolume': '6.05175647',
#    'openTime': '1674023256506',
#    'closeTime': '1674109656506',
#    'firstId': '8620987',
#    'lastId': '8624403',
#    'count': '3417'}},
#  'DIA/BUSD': {'symbol': 'DIA/BUSD',
#   'timestamp': 1674109617236,
#   'datetime': '2023-01-19T06:26:57.236Z',
#   'high': 0.342,
#   'low': 0.308,
#   'bid': 0.32,
#   'bidVolume': 125.0,
#   'ask': 0.321,
#   'askVolume': 3055.2,
#   'vwap': 0.32166295,
#   'open': 0.337,
#   'close': 0.32,
#   'last': 0.32,
#   'previousClose': 0.337,
#   'change': -0.017,
#   'percentage': -5.045,
#   'average': 0.3285,
#   'baseVolume': 637653.6,
#   'quoteVolume': 205109.5397,
#   'info': {'symbol': 'DIABUSD',
#    'priceChange': '-0.01700000',
#    'priceChangePercent': '-5.045',
#    'weightedAvgPrice': '0.32166295',
#    'prevClosePrice': '0.33700000',
#    'lastPrice': '0.32000000',
#    'lastQty': '751.20000000',
#    'bidPrice': '0.32000000',
#    'bidQty': '125.00000000',
#    'askPrice': '0.32100000',
#    'askQty': '3055.20000000',
#    'openPrice': '0.33700000',
#    'highPrice': '0.34200000',
#    'lowPrice': '0.30800000',
#    'volume': '637653.60000000',
#    'quoteVolume': '205109.53970000',
#    'openTime': '1674023217236',
#    'closeTime': '1674109617236',
#    'firstId': '4408420',
#    'lastId': '4410772',
#    'count': '2353'}},
#  ...}
